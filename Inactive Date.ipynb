# %%
import pandas
import numpy
import glob
import csv
import pydatastream
from pydatastream import Datastream
import os

# %%
df = pandas.read_csv('csvs/shanghai_equities_inactive_dates.csv')

# %%
df[df['WC07015'].notnull()]
# Out:
#       Unnamed: 0  CCY  SYMBOL              WC07015
# 1099        1099  NaN  CN:ACG  2004-09-15 00:00:00
# 1101        1101  NaN  CN:BAC  2007-12-26 00:00:00
# 1102        1102  NaN  CN:NEH  2004-09-22 00:00:00
# 1103        1103  NaN  CN:CXV  2010-01-05 00:00:00
# 1104        1104  NaN  CN:CNR  2015-05-21 00:00:00
# 1105        1105  NaN  CN:CKG  2015-05-26 00:00:00
# 1106        1106  NaN  CN:CSI  2005-09-16 00:00:00
# 1107        1107  NaN  CN:DAL  2004-09-15 00:00:00
# 1108        1108  NaN  CN:DLP  2007-12-13 00:00:00
# 1109        1109  NaN  CN:DBO  2008-02-19 00:00:00
# 1110        1110  NaN  CN:FUJ  2006-03-23 00:00:00
# 1111        1111  NaN  CN:HCM  2012-03-20 00:00:00
# 1112        1112  NaN  CN:SIC  2005-08-05 00:00:00
# 1113        1113  NaN  CN:HAC  2005-09-22 00:00:00
# 1114        1114  NaN  CN:HIS  2010-01-05 00:00:00
# 1115        1115  NaN  CN:HTA  2011-02-18 00:00:00
# 1116        1116  NaN  CN:HAH  2005-12-31 00:00:00
# ...

# %%
data = DWE.fetch('CN:CHC', DATATYPES, freq='M')

# %%
data
# Out:
#               MTBV      MV      P       PE    PTBV         VA        VO
# 2006-04-15   30.76   384.1   1.67      NaN   30.76        NaN   19362.6
# 2006-05-15   37.76   471.5   2.05      NaN   37.76        NaN   21260.0
# 2006-06-15   42.18   526.7   2.29      NaN   42.18        NaN   43599.2
# 2006-07-15   42.92   535.9   2.33      NaN   42.92        NaN   16414.6
# 2006-08-15   43.84   547.4   2.38      NaN   43.84        NaN   17694.7
# 2006-09-15   57.84   722.2   3.14      NaN   57.84        NaN   76217.4
# 2006-10-15   64.84   809.6   3.52      NaN   64.84        NaN   47306.6
# 2006-11-15   58.94   736.0   3.20      NaN   58.94        NaN   72392.2
# 2006-12-15   54.70   683.1   2.97      NaN   54.71        NaN   63895.8
# 2007-01-15   25.10   683.1   2.97      NaN   25.10        NaN       NaN
# 2007-02-15   28.74   782.0   3.40      NaN   28.74        NaN  125976.9
# 2007-03-15   41.33  1124.7   4.89      NaN   41.33        NaN  118456.8
# ...
